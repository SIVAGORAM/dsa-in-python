# %% [markdown]
# # Conditional Statements in Python (if, elif, else)
#
# ## Learning Objectives
#
# After completing this topic, you will be able to:
#
# - Understand decision-making in programming.
# - Learn how conditional statements work.
# - Use `if`, `elif`, and `else` effectively.
# - Write nested conditional statements.
# - Understand Boolean expressions.
# - Build logical thinking for DSA.
# - Avoid common mistakes.
# - Solve real-world decision-making problems.
#
# ---
#
# # Table of Contents
#
# 1. Introduction to Conditional Statements
# 2. Why Conditional Statements are Important
# 3. Flow of Execution
# 4. Boolean Expressions
# 5. Truthy and Falsy Values
# 6. The if Statement
# 7. The else Statement
# 8. The elif Statement
# 9. Nested Conditional Statements
# 10. Conditional (Ternary) Expression
# 11. Logical Operators with Conditions
# 12. Membership Operators in Conditions
# 13. Identity Operators in Conditions
# 14. Chained Comparisons
# 15. Short-Circuit Evaluation
# 16. Common Errors
# 17. Best Practices
# 18. Real-World Examples
# 19. DSA Applications
# 20. Interview Questions
# 21. Practice Exercises
# 22. Key Takeaways
#
# ---
#
# # 1. Introduction to Conditional Statements
#
# Programs often need to make decisions.
#
# Conditional statements allow a program to execute different blocks of code depending on whether a condition is **True** or **False**.
#
# Think of them as asking questions.
#
# Example:
#
# > Is the user eligible to vote?
#
# If Yes
#
# → Allow voting.
#
# If No
#
# → Show a message.
#
# Without conditional statements, every program would execute exactly the same way every time.
#
# ---
#
# # 2. Why Conditional Statements are Important
#
# Conditional statements help us:
#
# - Make decisions
# - Validate user input
# - Build intelligent programs
# - Control program flow
# - Solve DSA problems
# - Implement business logic
#
# Almost every software application uses conditional statements.
#
# Examples:
#
# - ATM Machine
# - Login System
# - Payment Gateway
# - Netflix Recommendations
# - Google Search
# - Amazon Product Suggestions
#
# ---
#
# # 3. Flow of Execution
#
# Python executes code from top to bottom.
#
# Whenever it encounters an `if` statement, it checks the condition.
#
# If the condition is True
#
# ↓
#
# Execute the block
#
# Else
#
# ↓
#
# Skip the block
#
# ---
#
# # 4. Boolean Expressions
#
# A Boolean expression always evaluates to either:
#
# ```
# True
# ```
#
# or
#
# ```
# False
# ```
#
# Example
#
# ```python
# print(10 > 5)
#
# print(5 == 5)
#
# print(3 < 1)
# ```
#
# Output
#
# ```
# True
# True
# False
# ```
#
# ---
#
# # 5. Truthy and Falsy Values
#
# Not every condition needs True or False directly.
#
# Python treats some values as **False** automatically.
#
# Falsy Values
#
# ```python
# False
# None
# 0
# 0.0
# ''
# []
# {}
# set()
# ```
#
# Everything else is Truthy.
#
# Example
#
# ```python
# name = ""
#
# if name:
#     print("Name exists")
# else:
#     print("Empty")
# ```
#
# Output
#
# ```
# Empty
# ```
#
# ---
#
# # 6. The if Statement
#
# The `if` statement executes a block only when its condition is True.
#
# Syntax
#
# ```python
# if condition:
#     statements
# ```
#
# Example
#
# ```python
# age = 20
#
# if age >= 18:
#     print("Eligible to Vote")
# ```
#
# Output
#
# ```
# Eligible to Vote
# ```
#
# ---
#
# # 7. The else Statement
#
# The `else` block executes when the `if` condition is False.
#
# Example
#
# ```python
# age = 16
#
# if age >= 18:
#     print("Eligible")
# else:
#     print("Not Eligible")
# ```
#
# Output
#
# ```
# Not Eligible
# ```
#
# ---
#
# # 8. The elif Statement
#
# Use `elif` to check multiple conditions.
#
# Example
#
# ```python
# marks = 85
#
# if marks >= 90:
#     print("Grade A")
# elif marks >= 75:
#     print("Grade B")
# elif marks >= 60:
#     print("Grade C")
# else:
#     print("Fail")
# ```
#
# Output
#
# ```
# Grade B
# ```
#
# Python checks conditions one by one.
#
# As soon as one condition becomes True, the remaining conditions are skipped.
#
# ---
#
# # 9. Nested Conditional Statements
#
# An `if` statement inside another `if` statement is called a nested conditional.
#
# Example
#
# ```python
# age = 25
# has_license = True
#
# if age >= 18:
#     if has_license:
#         print("You can drive.")
#     else:
#         print("License required.")
# else:
#     print("You are underage.")
# ```
#
# Output
#
# ```
# You can drive.
# ```
#
# ---
#
# # 10. Conditional (Ternary) Expression
#
# Python provides a shorter way to write simple conditions.
#
# Syntax
#
# ```python
# value_if_true if condition else value_if_false
# ```
#
# Example
#
# ```python
# age = 20
#
# message = "Adult" if age >= 18 else "Minor"
#
# print(message)
# ```
#
# Output
#
# ```
# Adult
# ```
#
# ---
#
# # 11. Logical Operators
#
# Example
#
# ```python
# age = 25
# salary = 60000
#
# if age >= 18 and salary > 50000:
#     print("Loan Approved")
# ```
#
# ---
#
# # 12. Membership Operators
#
# Example
#
# ```python
# course = "Python"
#
# if "P" in course:
#     print("Found")
# ```
#
# ---
#
# # 13. Identity Operators
#
# Example
#
# ```python
# a = [1, 2]
# b = a
#
# if a is b:
#     print("Same Object")
# ```
#
# ---
#
# # 14. Chained Comparisons
#
# Python allows chaining comparisons.
#
# Example
#
# ```python
# age = 25
#
# if 18 <= age <= 60:
#     print("Eligible")
# ```
#
# This is equivalent to
#
# ```python
# if age >= 18 and age <= 60:
# ```
#
# ---
#
# # 15. Short-Circuit Evaluation
#
# Example
#
# ```python
# x = 10
#
# if x > 5 or x / 0 > 2:
#     print("Executed")
# ```
#
# The second condition is never evaluated.
#
# No error occurs.
#
# ---
#
# # 16. Common Errors
#
# ## Missing Colon
#
# Wrong
#
# ```python
# if age >= 18
# ```
#
# Correct
#
# ```python
# if age >= 18:
# ```
#
# ---
#
# ## Incorrect Indentation
#
# Wrong
#
# ```python
# if age > 18:
# print(age)
# ```
#
# ---
#
# ## Using Assignment Instead of Comparison
#
# Wrong
#
# ```python
# if age = 18:
# ```
#
# Correct
#
# ```python
# if age == 18:
# ```
#
# ---
#
# ## Forgetting elif Order
#
# Wrong
#
# ```python
# marks = 95
#
# if marks >= 60:
#     print("Pass")
# elif marks >= 90:
#     print("Excellent")
# ```
#
# Output
#
# ```
# Pass
# ```
#
# Correct
#
# ```python
# if marks >= 90:
#     print("Excellent")
# elif marks >= 60:
#     print("Pass")
# ```
#
# ---
#
# # 17. Best Practices
#
# - Write readable conditions.
# - Avoid deeply nested code.
# - Use meaningful variable names.
# - Order conditions carefully.
# - Keep indentation consistent.
# - Prefer chained comparisons when possible.
#
# ---
#
# # 18. Real-World Examples
#
# ## ATM Withdrawal
#
# ```python
# balance = 10000
# amount = 3000
#
# if amount <= balance:
#     print("Transaction Successful")
# else:
#     print("Insufficient Balance")
# ```
#
# ---
#
# ## Login System
#
# ```python
# username = "admin"
# password = "1234"
#
# if username == "admin" and password == "1234":
#     print("Login Successful")
# else:
#     print("Invalid Credentials")
# ```
#
# ---
#
# ## Even or Odd
#
# ```python
# number = 10
#
# if number % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
#
# ---
#
# ## Leap Year
#
# ```python
# year = 2024
#
# if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
#     print("Leap Year")
# else:
#     print("Not a Leap Year")
# ```
#
# ---
#
# # 19. DSA Applications
#
# Conditional statements are used in:
#
# - Binary Search
# - Linear Search
# - Sorting Algorithms
# - Trees
# - Graphs
# - Dynamic Programming
# - Greedy Algorithms
# - Sliding Window
# - Two Pointers
# - Backtracking
# - Recursion
# - BFS
# - DFS
#
# You will use `if`, `elif`, and `else` in almost every DSA problem.
#
# ---
#
# # 20. Interview Questions
#
# 1. What is a conditional statement?
# 2. Difference between `if` and `elif`?
# 3. Difference between `if` and nested `if`?
# 4. What is a ternary operator?
# 5. What are Truthy and Falsy values?
# 6. What is short-circuit evaluation?
# 7. Difference between `==` and `is` in conditions?
# 8. Why is indentation important?
# 9. Explain chained comparisons.
# 10. How does Python evaluate multiple `elif` conditions?
#
# ---
#
# # 21. Practice Exercises
#
# Beginner
#
# 1. Check whether a number is positive or negative.
# 2. Find the larger of two numbers.
# 3. Find the largest of three numbers.
# 4. Check even or odd.
# 5. Check voting eligibility.
#
# Intermediate
#
# 6. Grade calculator.
# 7. Leap year checker.
# 8. ATM withdrawal system.
# 9. Login authentication.
# 10. Electricity bill calculator.
#
# Advanced
#
# 11. BMI calculator.
# 12. Income tax calculator.
# 13. Movie ticket booking system.
# 14. Student result management.
# 15. Bank account simulator.
#
# ---
#
# # 22. Key Takeaways
#
# - Conditional statements control the flow of a program.
# - `if` executes code when a condition is True.
# - `else` executes when the condition is False.
# - `elif` is used to check multiple conditions.
# - Nested conditionals allow complex decision-making.
# - Python supports ternary expressions for simple conditions.
# - Truthy and Falsy values simplify condition checks.
# - Strong understanding of conditional statements is essential for mastering DSA.

# %%
## If Statement
age =22

if age>=18:
    print("You are allowed to vote in the Elections")
# Out:
# You are allowed to vote in the Elections

# %%
## Else 
## the else statement executes a block of code if the condition in the if statement is False.

age = 16

if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## Elif
## The Elif Statement allows you to check multiple conditions. it stands for "else if"

age = 20

if age<13:
    print("You are a Child")
elif age<18:
    print("You are a teenager")
else:
    print ("You are an adult")
# Out:
# You are an adult

# %%
## Nested Conditional Statements
## You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements.

## Number even, odd, negative

num = int(input("Enter the Number:"))

if num>0:
    print("the number is positive")
    if num%2==0:
        print("The number is Even")
    else:
        print("the number is odd")

else:
    print("the number is Zero or negative")
# Out:
# the number is Zero or negative

# %%
## Practical Examples

## Determine if a year is a leap year using nested condition statement.

year = int(input("Enter the year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year,"is a lead Year")
        else:
            print(year,"is not a leap year")
    else:
        print(year,"is leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2024 is leap year

# %%
# Simple Calculator

print("===== Simple Calculator =====")

# Taking input from the user
num1 = float(input("Enter the first number: "))
operator = input("Enter an operator (+, -, *, /, //, %, **): ")
num2 = float(input("Enter the second number: "))

# Performing the operation
if operator == "+":
    print("Result:", num1 + num2)

elif operator == "-":
    print("Result:", num1 - num2)

elif operator == "*":
    print("Result:", num1 * num2)

elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Division by zero is not allowed.")

elif operator == "//":
    if num2 != 0:
        print("Result:", num1 // num2)
    else:
        print("Error: Division by zero is not allowed.")

elif operator == "%":
    if num2 != 0:
        print("Result:", num1 % num2)
    else:
        print("Error: Division by zero is not allowed.")

elif operator == "**":
    print("Result:", num1 ** num2)

else:
    print("Invalid operator! Please use +, -, *, /, //, %, or **.")
# Out:
# ===== Simple Calculator =====
# Result: 0.0

# %%
## Determine the ticket price based on age and whether the person is a student.

# Ticket Price Calculator

age = int(input("Enter your age: "))
is_student = input("Are you a student? (yes/no): ").lower()

if age < 5:
    print("Ticket Price: Free")

elif age < 18:
    if is_student == "yes":
        print("Ticket Price: ₹50")
    else:
        print("Ticket Price: ₹80")

elif age < 60:
    if is_student == "yes":
        print("Ticket Price: ₹100")
    else:
        print("Ticket Price: ₹150")

else:
    print("Ticket Price: ₹70")
# Out:
# Ticket Price: Free

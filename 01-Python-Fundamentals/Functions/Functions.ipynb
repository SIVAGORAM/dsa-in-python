# %% [markdown]
# # Functions in Python
#
# ## 🎯 Learning Objectives
#
# After completing this chapter, you will be able to:
#
# - Understand what functions are and why they are important.
# - Create and call functions.
# - Pass different types of arguments to functions.
# - Return values from functions.
# - Understand variable scope.
# - Work with recursive functions.
# - Use lambda functions.
# - Understand built-in functions.
# - Write reusable and modular code.
# - Build a strong foundation for DSA.
#
# ---
#
# # 📚 Table of Contents
#
# ## 1. Introduction to Functions
#
# - What is a Function?
# - Why Functions are Important
# - Advantages of Functions
# - Real-world Examples
# - Functions vs Methods
#
# ---
#
# ## 2. Defining Functions
#
# - Function Syntax
# - Function Declaration
# - Function Body
# - Naming Conventions
# - Docstrings
#
# ---
#
# ## 3. Calling Functions
#
# - Calling a Function
# - Calling Multiple Times
# - Function Execution Flow
#
# ---
#
# ## 4. Function Parameters
#
# - Parameters vs Arguments
# - Positional Arguments
# - Keyword Arguments
# - Default Arguments
# - Required Arguments
#
# ---
#
# ## 5. Default Parameters
#
# - Creating Default Parameters
# - Multiple Default Parameters
# - Rules for Default Parameters
#
# ---
#
# ## 6. Variable-Length Arguments
#
# - *args
# - **kwargs
# - Combining *args and **kwargs
#
# ---
#
# ## 7. Return Statement
#
# - Returning Values
# - Returning Multiple Values
# - Returning Tuples
# - Returning Lists
# - Returning Dictionaries
#
# ---
#
# ## 8. Variable Scope
#
# - Local Variables
# - Global Variables
# - global Keyword
# - nonlocal Keyword
#
# ---
#
# ## 9. Recursive Functions
#
# - Introduction
# - Base Case
# - Recursive Case
# - Examples
# - Advantages
# - Disadvantages
#
# ---
#
# ## 10. Lambda Functions
#
# - Anonymous Functions
# - Syntax
# - Using lambda with map()
# - filter()
# - reduce()
# - sorted()
#
# ---
#
# ## 11. Built-in Functions
#
# - print()
# - len()
# - max()
# - min()
# - sum()
# - type()
# - input()
# - range()
# - enumerate()
# - zip()
#
# ---
#
# ## 12. Function Documentation
#
# - Docstrings
# - help()
# - Writing Professional Documentation
#
# ---
#
# ## 13. Best Practices
#
# - Small Functions
# - Single Responsibility
# - Meaningful Names
# - Avoid Global Variables
# - Return Instead of Print
# - Write Reusable Functions
#
# ---
#
# ## 14. Common Errors
#
# - Missing Parameters
# - Incorrect Number of Arguments
# - Forgetting return
# - Indentation Errors
# - Variable Scope Errors
# - Mutable Default Arguments
#
# ---
#
# ## 15. Time Complexity
#
# - Constant Functions
# - Linear Functions
# - Recursive Functions
# - Space Complexity
#
# ---
#
# ## 16. DSA Connection
#
# Functions are used in:
#
# - Searching Algorithms
# - Sorting Algorithms
# - Recursion
# - Trees
# - Graphs
# - Dynamic Programming
# - Backtracking
# - Divide and Conquer
#
# ---
#
# ## 17. Interview Questions
#
# - What is a function?
# - Difference between parameters and arguments?
# - Difference between print() and return?
# - What are default arguments?
# - What are keyword arguments?
# - What are *args and **kwargs?
# - What is recursion?
# - What is variable scope?
# - What is a lambda function?
# - Why are functions important?
#
# ---
#
# ## 18. Practice Problems
#
# ### Beginner
#
# - Create a function to print your name.
# - Create a function to add two numbers.
# - Create a function to multiply two numbers.
# - Create a function to find the square.
# - Create a function to check even or odd.
#
# ### Intermediate
#
# - Calculator
# - Factorial
# - Fibonacci
# - Prime Number
# - Palindrome
# - Reverse String
# - Maximum of Three Numbers
#
# ### Advanced
#
# - Recursive Factorial
# - Recursive Fibonacci
# - Binary Search Function
# - Bubble Sort Function
# - Merge Sort Function
# - Quick Sort Function
#
# ---
#
# ## 19. Key Takeaways
#
# - Functions make code reusable.
# - Functions improve readability.
# - Functions reduce code duplication.
# - Functions are essential for modular programming.
# - Functions are the building blocks of every DSA algorithm.

# %% [markdown]
# # Introduction to Functions
#
# ## Definition
#
# A **function** is a reusable block of code that performs a specific task. Instead of writing the same code multiple times, you can write it once inside a function and call it whenever needed.
#
# Functions make programs easier to understand, maintain, test, and reuse. They are one of the fundamental building blocks of programming and are heavily used in Data Structures and Algorithms (DSA).
#
# ---
#
# ## Why Do We Need Functions?
#
# Imagine you need to calculate the sum of two numbers in ten different places in your program.
#
# Without functions, you would write the same code ten times.
#
# With functions, you write the code once and call the function whenever required.
#
# This reduces code duplication and makes programs easier to maintain.
#
# ---
#
# ## Advantages of Functions
#
# - Improve code readability.
# - Reduce code duplication.
# - Promote code reusability.
# - Make debugging easier.
# - Simplify testing.
# - Support modular programming.
# - Improve collaboration in large projects.
# - Make DSA implementations cleaner.
#
# ---
#
# ## Real-World Examples
#
# Functions are used in almost every software application:
#
# - User Login
# - Payment Processing
# - Sending Emails
# - Searching Data
# - Sorting Records
# - Database Operations
# - Image Processing
# - Machine Learning Models
#
# ---
#
# ## Function Syntax
#
# ```python
# def function_name(parameters):
#     # Function Body
#     statements
#     return value
# ```
#
# ---
#
# ## Example
#
# ```python
# def greet():
#     print("Hello, Welcome to Python!")
# ```
#
# Calling the function:
#
# ```python
# greet()
# ```
#
# ### Output
#
# ```
# Hello, Welcome to Python!
# ```
#
# ---
#
# ## Real-Life Analogy
#
# Think of a **function** like a coffee vending machine.
#
# ### Input
#
# - Coffee selection
# - Sugar level
#
# ↓
#
# ### Machine (Function)
#
# Processes your request
#
# ↓
#
# ### Output
#
# A cup of coffee
#
# Similarly,
#
# ```
# Input
# ↓
#
# Function
#
# ↓
#
# Output
# ```
#
# ---
#
# ## Functions vs Methods
#
# | Function | Method |
# |----------|---------|
# | Independent block of code | Belongs to an object |
# | Called directly | Called using an object |
# | Example: `print()` | Example: `"python".upper()` |
#
# ---
#
# ## DSA Connection
#
# Functions are the foundation of almost every Data Structures and Algorithms problem.
#
# Examples:
#
# - Binary Search
# - Bubble Sort
# - Merge Sort
# - Quick Sort
# - Tree Traversal
# - Graph Traversal
# - Dynamic Programming
# - Backtracking
#
# Every algorithm you learn in DSA will be implemented using functions.
#
# ---
#
# ## Key Points
#
# - A function performs a specific task.
# - Functions make code reusable.
# - Functions reduce code duplication.
# - Functions improve readability.
# - Functions are the foundation of modular programming.
# - Every DSA algorithm is implemented using functions.

# %%
## Syntax

def function_name(parameters):
    """DocString"""
    ## Function Body
    return expression

# %%
## Why Functions?

num=24
if num%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is even

# %%
def even_or_odd(num):
    """This function finds even or odd"""
    if num%2==0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
## Call this function
even_or_odd(24)
# Out:
# the number is even

# %%
## Function with multiple Parameters

def add(a,b):
    return a+b
result=add(2,4)
print(result)
# Out:
# 6

# %%
## Default Parameters

def greet(name):
    print(f"Hello {name} Welcome to Paradise")
greet("Siva")
# Out:
# Hello Siva Welcome to Paradise

# %%
## Default Parameters

def greet(name="Guest"):
    print(f"Hello {name} Welcome to Paradise")
greet()
# Out:
# Hello Guest Welcome to Paradise

# %%
### Variable Length Arguments
## Positions and Keywords arguments

def print_numbers(*siva):
    for number in siva:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"siva")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# siva

# %%
## Positional  arguments

def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,7,8,"siva")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# siva

# %%
## Keyword Arguments

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

# %%
print_details(name="siva",age="32",country="India")
# Out:
# name:siva
# age:32
# country:India

# %%
def print_details(*args, **kwargs):
    for val in args:
        print(f"Positional Argument: {val}")

    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
print_details(1, 2, 3, 4, "siva", name="siva", age="22", country="India")
# Out:
# Positional Argument: 1
# Positional Argument: 2
# Positional Argument: 3
# Positional Argument: 4
# Positional Argument: siva
# name: siva
# age: 22
# country: India

# %%
## Return Statements

def multiply(a,b):
    return a*b
multiply(2,3)
# Out:
# 6

# %%
## Return Multiple Parameters

def multiply(a,b):
    return a*b,a

multiply(2,3)
# Out:
# (6, 2)

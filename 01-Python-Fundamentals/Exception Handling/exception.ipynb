# %% [markdown]
# # Exception Handling in Python
#
# ## Introduction
#
# **Exception handling** is a mechanism in Python that allows a program to handle runtime errors gracefully without terminating unexpectedly. Instead of crashing when an error occurs, Python provides tools to detect, handle, and recover from exceptions, allowing the program to continue executing or exit gracefully.
#
# Python uses the following keywords for exception handling:
#
# - `try`
# - `except`
# - `else`
# - `finally`
# - `raise`
#
# In this chapter, you will learn:
#
# - What exceptions are
# - Why exception handling is important
# - Common built-in exceptions
# - The `try`, `except`, `else`, and `finally` blocks
# - Raising custom exceptions using `raise`
# - Best practices for exception handling
#
# ---
#
# # What are Exceptions?
#
# An **exception** is an event that occurs during the execution of a program that interrupts the normal flow of instructions.
#
# When an exception occurs, Python creates an exception object. If the exception is not handled, the program terminates and displays an error message (traceback).
#
# Exception handling allows you to catch these errors and respond appropriately instead of letting the program crash.
#
# ---
#
# ## Common Built-in Exceptions
#
# | Exception | Description |
# |-----------|-------------|
# | `ZeroDivisionError` | Raised when dividing a number by zero. |
# | `FileNotFoundError` | Raised when attempting to open a file that does not exist. |
# | `ValueError` | Raised when a function receives an argument of the correct type but an invalid value. |
# | `TypeError` | Raised when an operation or function is applied to an object of an inappropriate type. |
# | `IndexError` | Raised when accessing a list or tuple using an invalid index. |
# | `KeyError` | Raised when trying to access a dictionary key that does not exist. |
# | `NameError` | Raised when a variable or function name is not defined. |
# | `AttributeError` | Raised when an object does not have the requested attribute. |
# | `ImportError` | Raised when a module or object cannot be imported. |
# | `ModuleNotFoundError` | Raised when the specified module cannot be found. |
# | `OverflowError` | Raised when a calculation exceeds the maximum numeric limit. |
# | `MemoryError` | Raised when the system runs out of memory. |
#
# ---
#
# ## Example
#
# ```python
# num = 10
# result = num / 0
#
# print(result)
# ```
#
# ### Output
#
# ```text
# ZeroDivisionError: division by zero
# ```
#
# Since the exception is not handled, the program stops immediately.
#
# ---
#
# ## Why Do We Need Exception Handling?
#
# Exception handling helps us:
#
# - Prevent unexpected program crashes.
# - Handle errors gracefully.
# - Display meaningful error messages.
# - Improve user experience.
# - Make programs more reliable and robust.
# - Continue program execution whenever possible.
#
# ---
#
# ## Real-World Examples
#
# - Reading a file that may not exist.
# - Taking user input that may be invalid.
# - Connecting to a database.
# - Making API requests.
# - Performing mathematical calculations.
# - Accessing dictionary keys or list elements safely.
#
# ---
#
# ## Key Takeaways
#
# - An **exception** is a runtime error that interrupts the normal execution of a program.
# - Python provides built-in exception handling using `try`, `except`, `else`, and `finally`.
# - Handling exceptions makes programs more robust, reliable, and user-friendly.
# - Understanding common exceptions is essential for writing error-free Python code.

# %%
## Exception Try, except block

try:
    a = b
except:
    print("THe variable has not been assigned ")
# Out:
# THe variable has not been assigned

# %%
## Exception Try, except block

try:
    a = b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater then 0")
# Out:
# division by zero
# Please enter the denominator greater then 0

# %%
try:
    result=1/2
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater then 0")

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator greater then 0")
except Exception as exl:
    print(exl)
    print('Main Exception got caught here')
# Out:
# name 'b' is not defined
# Main Exception got caught here

# %%
try:
    num=int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
# Out:
# Enter denominator greater than 0

# %%
## Try, except, else block

try:
    num=int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
# Out:
# the result is -5.0

# %%
## Try, except, else and finally

try:
    num=int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You can't divide by zero!")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    print("Execution complete")
# Out:
# the result is 0.8333333333333334
# Execution complete

# %%
try:
    file = open('example.txt', 'r')
    content = file.read()
    print(content)

except FileNotFoundError:
    print("The file does not exist.")

finally:
    if 'file' in locals() and not file.closed:
        file.close()
        print("File closed.")
# Out:
# The file does not exist.

# %% [markdown]
# # Classes and Objects in Python
#
# ## Introduction
#
# **Object-Oriented Programming (OOP)** is a programming paradigm that organizes code using **objects**, which represent real-world entities. OOP allows developers to model real-world scenarios by combining data (attributes) and behavior (methods) into reusable and organized structures called **classes**.
#
# Python is a multi-paradigm programming language that fully supports Object-Oriented Programming, making it easier to build scalable, maintainable, and reusable applications.
#
# In this chapter, you will learn everything you need to know about **Classes and Objects**, from the basics to advanced OOP concepts.
#
# ---
#
# ## What is Object-Oriented Programming (OOP)?
#
# **Object-Oriented Programming (OOP)** is a programming approach in which programs are designed using **classes** and **objects**.
#
# Instead of writing code as a sequence of functions, OOP organizes related data and functionality into objects, making programs easier to understand, maintain, and extend.
#
# ---
#
# ## Why Learn OOP?
#
# Object-Oriented Programming helps developers:
#
# - Organize code into reusable components.
# - Model real-world entities effectively.
# - Improve code readability and maintainability.
# - Reduce code duplication through inheritance.
# - Build scalable and modular applications.
# - Follow industry-standard software development practices.
#
# ---
#
# ## Real-World Examples
#
# Everything around us can be represented as an object.
#
# | Class | Object |
# |--------|--------|
# | Car | Tesla Model 3 |
# | Student | John |
# | Employee | Alice |
# | Bank Account | Account #12345 |
# | Mobile Phone | iPhone 16 |
# | Laptop | Dell XPS 15 |
#
# Each object has:
#
# - **Attributes (Properties)** → Characteristics of the object.
# - **Methods (Behaviors)** → Actions the object can perform.
#
# For example:
#
# **Class:** Car
#
# **Attributes:**
# - Brand
# - Color
# - Speed
#
# **Methods:**
# - Start()
# - Stop()
# - Accelerate()
#
# ---
#
# ## Topics Covered
#
# This chapter covers:
#
# - Introduction to OOP
# - Classes
# - Objects
# - Attributes
# - Methods
# - The `self` keyword
# - Constructors (`__init__`)
# - Instance variables
# - Class variables
# - Instance methods
# - Class methods
# - Static methods
# - Inheritance
# - Polymorphism
# - Encapsulation
# - Abstraction
# - Magic (Dunder) Methods
# - Composition
# - Aggregation
# - Method Resolution Order (MRO)
# - Operator Overloading
# - Exception handling in OOP
# - Best Practices
#
# ---
#
# ## Key Takeaways
#
# - **OOP** is a programming paradigm based on classes and objects.
# - A **class** is a blueprint for creating objects.
# - An **object** is an instance of a class.
# - OOP promotes code reusability, modularity, and maintainability.
# - Python provides powerful features to implement Object-Oriented Programming efficiently.

# %%
## A Class is a blue print for creating objects. Attributes, methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows = 4

print(audi.windows)
# Out:
# 4

# %%
dir()
# Out:
# ['Car',
#  'In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'audi',
#  'bmw',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit']

# %%
## Instance variable and methods

class Dog:
    ## Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

## Create Object
dog1=Dog("Buddfy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddfy
# 3

# %%
dog2=Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Define a class with instance methods

class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
## Modeling a Bank Account

## Define a Class for Bank Account

class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New Balance is {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance


## Create an account
account = BankAccount("Siva", 500000)

print(account.balance)

account.deposit(10000)
account.withdraw(5000)

print("Current Balance:", account.get_balance())
# Out:
# 500000
# 10000 is deposited. New Balance is 510000
# 5000 is withdrawn. New Balance is 505000
# Current Balance: 505000

# %% [markdown]
# ## Conclusion:
#
# Object-Oriented Programming(OOp) allows you to model real world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance and methods, and use them to perform various operations. Understanding these concepts is fundament to writing effective and maintainable python code.

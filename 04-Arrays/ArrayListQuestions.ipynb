# %% [markdown]
# # 🐍 Python Lists (Arrays) Mastery Challenge (200 Problems)
#
# > **Goal:** Master Python Lists (Arrays) from beginner to advanced level and build a strong foundation for Data Structures & Algorithms.
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing these problems, you will be able to:
#
# - Create and manipulate lists
# - Perform CRUD operations
# - Traverse lists
# - Search and update elements
# - Work with nested lists
# - Solve array-based interview questions
# - Understand time complexity
# - Build problem-solving skills for DSA
#
# ---
#
# # 🟢 Level 1 — List Fundamentals (20 Problems)
#
# 1. Create an empty list.
# 2. Create a list of integers.
# 3. Create a list of strings.
# 4. Create a mixed data type list.
# 5. Print all elements.
# 6. Print the first element.
# 7. Print the last element.
# 8. Print the middle element.
# 9. Find the length of a list.
# 10. Check the data type of a list.
# 11. Create a list using `list()`.
# 12. Create a list using user input.
# 13. Access elements using positive indexing.
# 14. Access elements using negative indexing.
# 15. Check whether a list is empty.
# 16. Copy a list.
# 17. Compare two lists.
# 18. Print memory address using `id()`.
# 19. Create nested lists.
# 20. Access elements of nested lists.
#
# ---
#
# # 🟢 Level 2 — Traversing Lists (20 Problems)
#
# 21. Traverse using a `for` loop.
# 22. Traverse using a `while` loop.
# 23. Traverse using `enumerate()`.
# 24. Print index and value.
# 25. Traverse in reverse order.
# 26. Traverse every second element.
# 27. Traverse odd indices.
# 28. Traverse even indices.
# 29. Sum all elements.
# 30. Find the product of all elements.
# 31. Count positive numbers.
# 32. Count negative numbers.
# 33. Count even numbers.
# 34. Count odd numbers.
# 35. Count vowels in a character list.
# 36. Find maximum while traversing.
# 37. Find minimum while traversing.
# 38. Count occurrences of an element.
# 39. Print elements greater than average.
# 40. Print elements smaller than average.
#
# ---
#
# # 🟢 Level 3 — List Operations (20 Problems)
#
# 41. Append an element.
# 42. Insert at the beginning.
# 43. Insert at a specific position.
# 44. Extend one list with another.
# 45. Remove an element.
# 46. Remove by index.
# 47. Remove all occurrences of an element.
# 48. Pop the last element.
# 49. Pop an element by index.
# 50. Clear the list.
# 51. Reverse a list.
# 52. Sort ascending.
# 53. Sort descending.
# 54. Create a sorted copy.
# 55. Find the index of an element.
# 56. Count occurrences using `count()`.
# 57. Check membership using `in`.
# 58. Concatenate two lists.
# 59. Repeat a list using `*`.
# 60. Delete a list.
#
# ---
#
# # 🟢 Level 4 — Slicing (20 Problems)
#
# 61. Print first five elements.
# 62. Print last five elements.
# 63. Slice from index 2 to 8.
# 64. Reverse using slicing.
# 65. Every second element.
# 66. Every third element.
# 67. Odd indexed elements.
# 68. Even indexed elements.
# 69. Copy using slicing.
# 70. Remove first element using slicing.
# 71. Remove last element.
# 72. Remove middle elements.
# 73. Rotate left by one.
# 74. Rotate right by one.
# 75. Split list into two halves.
# 76. Extract first half.
# 77. Extract second half.
# 78. Extract alternate elements.
# 79. Reverse alternate elements.
# 80. Slice nested lists.
#
# ---
#
# # 🟢 Level 5 — Searching (20 Problems)
#
# 81. Linear Search.
# 82. Find first occurrence.
# 83. Find last occurrence.
# 84. Find all occurrences.
# 85. Search using `in`.
# 86. Search using `index()`.
# 87. Search ignoring case.
# 88. Count duplicates.
# 89. Check if all elements exist.
# 90. Find missing element.
# 91. Search in nested lists.
# 92. Find nearest value.
# 93. Find closest number.
# 94. Search multiple values.
# 95. Search strings.
# 96. Search longest word.
# 97. Search shortest word.
# 98. Search prime numbers.
# 99. Search palindrome numbers.
# 100. Search Armstrong numbers.
#
# ---
#
# # 🟢 Level 6 — List Methods (20 Problems)
#
# 101. Practice `append()`.
# 102. Practice `extend()`.
# 103. Practice `insert()`.
# 104. Practice `remove()`.
# 105. Practice `pop()`.
# 106. Practice `clear()`.
# 107. Practice `sort()`.
# 108. Practice `reverse()`.
# 109. Practice `copy()`.
# 110. Practice `count()`.
# 111. Practice `index()`.
# 112. Combine methods.
# 113. Remove duplicates.
# 114. Convert string to list.
# 115. Convert list to string.
# 116. Join words.
# 117. Split sentence.
# 118. Flatten nested lists.
# 119. Clone nested lists.
# 120. Merge multiple lists.
#
# ---
#
# # 🟢 Level 7 — Logic Building (20 Problems)
#
# 121. Find largest element.
# 122. Find smallest element.
# 123. Find second largest.
# 124. Find second smallest.
# 125. Find third largest.
# 126. Find average.
# 127. Find median.
# 128. Find mode.
# 129. Find range.
# 130. Find cumulative sum.
# 131. Running average.
# 132. Prefix sums.
# 133. Suffix sums.
# 134. Difference array.
# 135. Rotate left.
# 136. Rotate right.
# 137. Swap first and last.
# 138. Swap adjacent elements.
# 139. Reverse in-place.
# 140. Reverse without built-in methods.
#
# ---
#
# # 🟢 Level 8 — Interview Questions (20 Problems)
#
# 141. Remove duplicates.
# 142. Move zeros to end.
# 143. Move negatives to front.
# 144. Segregate even and odd.
# 145. Merge sorted lists.
# 146. Find union.
# 147. Find intersection.
# 148. Find symmetric difference.
# 149. Find missing number.
# 150. Find repeating number.
# 151. Find duplicate number.
# 152. Find unique number.
# 153. Maximum difference.
# 154. Minimum difference.
# 155. Pair with given sum.
# 156. Triplet with given sum.
# 157. Majority element.
# 158. Leaders in array.
# 159. Equilibrium index.
# 160. Frequency of elements.
#
# ---
#
# # 🟢 Level 9 — Advanced Problems (20 Problems)
#
# 161. Kadane's Algorithm.
# 162. Maximum Subarray Sum.
# 163. Minimum Subarray Sum.
# 164. Maximum Product Subarray.
# 165. Stock Buy and Sell.
# 166. Trapping Rain Water.
# 167. Container With Most Water.
# 168. Merge Intervals.
# 169. Spiral Matrix.
# 170. Rotate Matrix.
# 171. Diagonal Traversal.
# 172. Pascal Triangle.
# 173. Dutch National Flag.
# 174. Product Except Self.
# 175. Sliding Window Maximum.
# 176. Longest Consecutive Sequence.
# 177. Two Sum.
# 178. Three Sum.
# 179. Four Sum.
# 180. Merge K Sorted Lists.
#
# ---
#
# # 🔴 Level 10 — Projects (20 Problems)
#
# 181. Student Marks Management System.
# 182. Employee Database.
# 183. Contact Book.
# 184. Shopping Cart.
# 185. Inventory Management.
# 186. Expense Tracker.
# 187. Attendance System.
# 188. Library Management.
# 189. Hospital Queue.
# 190. Cricket Scoreboard.
# 191. Movie Rating System.
# 192. Weather Analyzer.
# 193. Banking Transactions.
# 194. Music Playlist.
# 195. To-Do List Manager.
# 196. Parking Lot System.
# 197. Online Quiz.
# 198. Restaurant Billing.
# 199. Airline Reservation.
# 200. Mini Spreadsheet.
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|-----------------------------|---------:|
# | 🟢 Level 1 | Fundamentals | 20 |
# | 🟢 Level 2 | Traversing | 20 |
# | 🟢 Level 3 | Operations | 20 |
# | 🟢 Level 4 | Slicing | 20 |
# | 🟢 Level 5 | Searching | 20 |
# | 🟢 Level 6 | List Methods | 20 |
# | 🟢 Level 7 | Logic Building | 20 |
# | 🟢 Level 8 | Interview Questions | 20 |
# | 🟢 Level 9 | Advanced DSA | 20 |
# | 🔴 Level 10 | Mini Projects | 20 |
#
# ## **Total Problems: 200**
#
# ---
#
# # 🎯 Skills You'll Master
#
# By completing these 200 problems, you'll master:
#
# - ✅ Python Lists (Arrays)
# - ✅ Indexing & Slicing
# - ✅ Traversal Techniques
# - ✅ CRUD Operations
# - ✅ Searching & Sorting Basics
# - ✅ List Methods
# - ✅ Nested Lists
# - ✅ Time Complexity
# - ✅ Logic Building
# - ✅ Interview-Ready Array Problems
# - ✅ Foundation for DSA Topics like Stacks, Queues, Heaps, Graphs, and Dynamic Programming
#
# ---
#
# # 🚀 Next Learning Path
#
# After mastering Python Lists (Arrays), continue with:
#
# 1. Strings
# 2. Recursion
# 3. Searching Algorithms
# 4. Sorting Algorithms
# 5. Hashing
# 6. Linked Lists
# 7. Stacks
# 8. Queues
# 9. Trees
# 10. Graphs

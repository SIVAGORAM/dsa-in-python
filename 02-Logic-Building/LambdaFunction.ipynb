# %% [markdown]
# # 🐍 Python Lambda Functions Mastery Challenge (70 Problems)
#
# > **Goal:** Master Lambda Functions from beginner to advanced level and understand where they are useful in Python programming and DSA.
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Understand lambda function syntax.
# - Convert normal functions into lambda functions.
# - Use lambda with built-in functions.
# - Sort complex data structures.
# - Use lambda with higher-order functions.
# - Solve interview-style problems.
# - Know when to use and when not to use lambda functions.
#
# ---
#
# # 🟢 Level 1 — Lambda Fundamentals (10 Problems)
#
# > Learn the syntax of lambda functions.
#
# ---
#
# ## 1. Create a lambda function to print "Hello World".
#
# ---
#
# ## 2. Create a lambda function that adds two numbers.
#
# ---
#
# ## 3. Create a lambda function that subtracts two numbers.
#
# ---
#
# ## 4. Create a lambda function that multiplies two numbers.
#
# ---
#
# ## 5. Create a lambda function that divides two numbers.
#
# ---
#
# ## 6. Create a lambda function to find the square of a number.
#
# ---
#
# ## 7. Create a lambda function to find the cube of a number.
#
# ---
#
# ## 8. Create a lambda function to check whether a number is even.
#
# ---
#
# ## 9. Create a lambda function to check whether a number is odd.
#
# ---
#
# ## 10. Convert five normal functions into lambda functions.
#
# ---
#
# # 🟢 Level 2 — Multiple Arguments (10 Problems)
#
# ---
#
# ## 11. Add three numbers.
#
# ---
#
# ## 12. Multiply four numbers.
#
# ---
#
# ## 13. Find the largest of two numbers.
#
# ---
#
# ## 14. Find the largest of three numbers.
#
# ---
#
# ## 15. Find the smallest of three numbers.
#
# ---
#
# ## 16. Find the average of five numbers.
#
# ---
#
# ## 17. Calculate simple interest.
#
# ---
#
# ## 18. Calculate the area of a rectangle.
#
# ---
#
# ## 19. Calculate the area of a circle.
#
# ---
#
# ## 20. Calculate the BMI.
#
# ---
#
# # 🟢 Level 3 — Conditional Lambda Expressions (10 Problems)
#
# ---
#
# ## 21. Check if a number is positive or negative.
#
# ---
#
# ## 22. Check if a person is eligible to vote.
#
# ---
#
# ## 23. Find the maximum of two numbers.
#
# ---
#
# ## 24. Check whether a number is divisible by 5.
#
# ---
#
# ## 25. Check whether a number is divisible by both 3 and 5.
#
# ---
#
# ## 26. Return "Pass" or "Fail" based on marks.
#
# ---
#
# ## 27. Return "Adult" or "Minor".
#
# ---
#
# ## 28. Check whether a character is a vowel.
#
# ---
#
# ## 29. Return the absolute value of a number.
#
# ---
#
# ## 30. Return the sign of a number (+, -, 0).
#
# ---
#
# # 🟢 Level 4 — Lambda with `map()` (10 Problems)
#
# ---
#
# ## 31. Square every number in a list.
#
# ---
#
# ## 32. Cube every number.
#
# ---
#
# ## 33. Convert Celsius to Fahrenheit.
#
# ---
#
# ## 34. Convert Fahrenheit to Celsius.
#
# ---
#
# ## 35. Convert strings to uppercase.
#
# ---
#
# ## 36. Convert strings to lowercase.
#
# ---
#
# ## 37. Find the length of every word.
#
# ---
#
# ## 38. Multiply every element by 10.
#
# ---
#
# ## 39. Add 5 to every element.
#
# ---
#
# ## 40. Remove leading and trailing spaces.
#
# ---
#
# # 🟢 Level 5 — Lambda with `filter()` (10 Problems)
#
# ---
#
# ## 41. Filter even numbers.
#
# ---
#
# ## 42. Filter odd numbers.
#
# ---
#
# ## 43. Filter positive numbers.
#
# ---
#
# ## 44. Filter negative numbers.
#
# ---
#
# ## 45. Filter numbers greater than 50.
#
# ---
#
# ## 46. Filter names longer than five characters.
#
# ---
#
# ## 47. Filter palindrome words.
#
# ---
#
# ## 48. Filter prime numbers.
#
# ---
#
# ## 49. Filter students who passed.
#
# ---
#
# ## 50. Filter employees earning more than ₹50,000.
#
# ---
#
# # 🟢 Level 6 — Lambda with `sorted()` (10 Problems)
#
# ---
#
# ## 51. Sort numbers in ascending order.
#
# ---
#
# ## 52. Sort numbers in descending order.
#
# ---
#
# ## 53. Sort strings alphabetically.
#
# ---
#
# ## 54. Sort strings by length.
#
# ---
#
# ## 55. Sort tuples by the first element.
#
# ---
#
# ## 56. Sort tuples by the second element.
#
# ---
#
# ## 57. Sort dictionaries by values.
#
# ---
#
# ## 58. Sort employees by salary.
#
# ---
#
# ## 59. Sort students by marks.
#
# ---
#
# ## 60. Sort products by price.
#
# ---
#
# # 🟢 Level 7 — Lambda with `reduce()` (10 Problems)
#
# > Import `reduce` from `functools`.
#
# ---
#
# ## 61. Find the sum of all numbers.
#
# ---
#
# ## 62. Find the product of all numbers.
#
# ---
#
# ## 63. Find the maximum number.
#
# ---
#
# ## 64. Find the minimum number.
#
# ---
#
# ## 65. Concatenate all strings.
#
# ---
#
# ## 66. Find the factorial of a number.
#
# ---
#
# ## 67. Multiply all odd numbers.
#
# ---
#
# ## 68. Find the total marks of students.
#
# ---
#
# ## 69. Count total characters in a list of words.
#
# ---
#
# ## 70. Find the longest word.
#
# ---
#
# # 🟢 Level 8 — Logic Building (10 Problems)
#
# ---
#
# ## 71. Find the square of even numbers only.
#
# ---
#
# ## 72. Find cubes of odd numbers.
#
# ---
#
# ## 73. Convert names to title case.
#
# ---
#
# ## 74. Remove duplicate words using lambda.
#
# ---
#
# ## 75. Sort names ignoring case.
#
# ---
#
# ## 76. Find the highest-paid employee.
#
# ---
#
# ## 77. Find the youngest student.
#
# ---
#
# ## 78. Count vowels in every word.
#
# ---
#
# ## 79. Calculate grades using lambda.
#
# ---
#
# ## 80. Create a mini calculator using lambda functions.
#
# ---
#
# # 🔴 Level 9 — Pre-DSA Challenges (10 Problems)
#
# ---
#
# ## 81. Sort intervals by starting point.
#
# ---
#
# ## 82. Sort graph edges by weight.
#
# ---
#
# ## 83. Sort coordinates by x-value.
#
# ---
#
# ## 84. Sort coordinates by y-value.
#
# ---
#
# ## 85. Find the maximum pair.
#
# ---
#
# ## 86. Sort matrix rows by sum.
#
# ---
#
# ## 87. Sort words by frequency.
#
# ---
#
# ## 88. Find the top scorer from student records.
#
# ---
#
# ## 89. Group words by length (using sorting).
#
# ---
#
# ## 90. Sort dictionaries by multiple keys.
#
# ---
#
# # ⭐ Bonus Mini Projects
#
# 1. Student Result Analyzer
# 2. Employee Salary Sorter
# 3. Product Price Analyzer
# 4. Movie Rating Sorter
# 5. Contact Book
# 6. Inventory Manager
# 7. Weather Data Analyzer
# 8. Cricket Scoreboard
# 9. Expense Tracker
# 10. Library Book Sorter
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|----------------------------|---------:|
# | 🟢 Level 1 | Lambda Fundamentals | 10 |
# | 🟢 Level 2 | Multiple Arguments | 10 |
# | 🟢 Level 3 | Conditional Expressions | 10 |
# | 🟢 Level 4 | Lambda + map() | 10 |
# | 🟢 Level 5 | Lambda + filter() | 10 |
# | 🟢 Level 6 | Lambda + sorted() | 10 |
# | 🟢 Level 7 | Lambda + reduce() | 10 |
# | 🟢 Level 8 | Logic Building | 10 |
# | 🔴 Level 9 | Pre-DSA Challenges | 10 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 100**
#
# ---
#
# # 🎯 Skills You'll Master
#
# By completing these challenges, you'll confidently understand:
#
# - ✅ Lambda syntax
# - ✅ Anonymous functions
# - ✅ Conditional expressions in lambda
# - ✅ Lambda with `map()`
# - ✅ Lambda with `filter()`
# - ✅ Lambda with `reduce()`
# - ✅ Lambda with `sorted()`
# - ✅ Sorting complex data structures
# - ✅ Functional programming basics
# - ✅ Real-world use cases
# - ✅ Interview-level lambda questions
#
# > **🚀 DSA Readiness:** After solving these 100 problems, you'll know when and how to use lambda functions effectively in Python. While lambda functions are not the core of DSA, they are frequently used for sorting, custom key functions, data transformation, filtering, and writing concise Python code in coding interviews.

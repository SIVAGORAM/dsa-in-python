# %% [markdown]
# # 🐍 Python Tuples Mastery Challenge (80 Problems)
#
# > **Goal:** Master Python Tuples from beginner to advanced level and build a strong foundation for immutable data structures before starting Data Structures & Algorithms (DSA).
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Create and manipulate tuples.
# - Access tuple elements efficiently.
# - Understand tuple immutability.
# - Master tuple methods.
# - Use tuple packing and unpacking.
# - Work with nested tuples.
# - Solve real-world problems using tuples.
# - Understand where tuples are used in DSA.
#
# ---
#
# # 🟢 Level 1 — Tuple Fundamentals (10 Problems)
#
# > Learn the basics of tuples.
#
# ---
#
# ## 1. Create an Empty Tuple
#
# ---
#
# ## 2. Create a Tuple with Integers
#
# Example
#
# ```
# (10, 20, 30, 40)
# ```
#
# ---
#
# ## 3. Create a Tuple with Strings
#
# ---
#
# ## 4. Create a Mixed Data Type Tuple
#
# ---
#
# ## 5. Create a Single-Element Tuple
#
# ---
#
# ## 6. Create a Tuple Using `tuple()`
#
# ---
#
# ## 7. Create a Tuple from a List
#
# ---
#
# ## 8. Create a Tuple from a String
#
# ---
#
# ## 9. Find the Length of a Tuple
#
# ---
#
# ## 10. Print Every Element of a Tuple
#
# ---
#
# # 🟢 Level 2 — Accessing Tuple Elements (10 Problems)
#
# ---
#
# ## 11. Access the First Element
#
# ---
#
# ## 12. Access the Last Element
#
# ---
#
# ## 13. Access an Element Using Positive Indexing
#
# ---
#
# ## 14. Access an Element Using Negative Indexing
#
# ---
#
# ## 15. Slice the First Three Elements
#
# ---
#
# ## 16. Slice the Last Three Elements
#
# ---
#
# ## 17. Reverse a Tuple Using Slicing
#
# ---
#
# ## 18. Check Whether an Element Exists
#
# ---
#
# ## 19. Find the Index of an Element
#
# ---
#
# ## 20. Count Occurrences of an Element
#
# ---
#
# # 🟢 Level 3 — Tuple Operations (10 Problems)
#
# ---
#
# ## 21. Concatenate Two Tuples
#
# ---
#
# ## 22. Repeat a Tuple Multiple Times
#
# ---
#
# ## 23. Find the Maximum Element
#
# ---
#
# ## 24. Find the Minimum Element
#
# ---
#
# ## 25. Find the Sum of Numeric Elements
#
# ---
#
# ## 26. Sort a Tuple
#
# ---
#
# ## 27. Convert a Tuple into a List
#
# ---
#
# ## 28. Convert a List into a Tuple
#
# ---
#
# ## 29. Find the Average of Numeric Elements
#
# ---
#
# ## 30. Find the Product of Numeric Elements
#
# ---
#
# # 🟢 Level 4 — Tuple Immutability (10 Problems)
#
# ---
#
# ## 31. Try to Modify an Element and Observe the Error
#
# ---
#
# ## 32. Update a Tuple by Converting It into a List
#
# ---
#
# ## 33. Add an Element Using List Conversion
#
# ---
#
# ## 34. Remove an Element Using List Conversion
#
# ---
#
# ## 35. Delete an Entire Tuple
#
# ---
#
# ## 36. Store a List Inside a Tuple
#
# ---
#
# ## 37. Modify the List Inside a Tuple
#
# ---
#
# ## 38. Check Whether a Tuple Can Be Used as a Dictionary Key
#
# ---
#
# ## 39. Create an Immutable Configuration Tuple
#
# ---
#
# ## 40. Explain Why Tuples are Immutable
#
# ---
#
# # 🟢 Level 5 — Tuple Methods (10 Problems)
#
# ---
#
# ## 41. Use `count()`
#
# ---
#
# ## 42. Count Duplicate Values
#
# ---
#
# ## 43. Count Even Numbers
#
# ---
#
# ## 44. Count Odd Numbers
#
# ---
#
# ## 45. Use `index()`
#
# ---
#
# ## 46. Find the First Occurrence of an Element
#
# ---
#
# ## 47. Find the Position of a String
#
# ---
#
# ## 48. Search for a Non-Existing Element
#
# ---
#
# ## 49. Compare `count()` and `index()`
#
# ---
#
# ## 50. Build a Search Program Using Tuple Methods
#
# ---
#
# # 🟢 Level 6 — Packing & Unpacking (10 Problems)
#
# ---
#
# ## 51. Pack Multiple Values into a Tuple
#
# ---
#
# ## 52. Unpack a Tuple into Variables
#
# ---
#
# ## 53. Swap Two Variables Using Tuple Unpacking
#
# ---
#
# ## 54. Unpack Only the First Two Values
#
# ---
#
# ## 55. Use Extended Unpacking (`*`)
#
# Example
#
# ```
# first, *middle, last
# ```
#
# ---
#
# ## 56. Return Multiple Values from a Function
#
# ---
#
# ## 57. Receive Multiple Values from a Function
#
# ---
#
# ## 58. Ignore Values While Unpacking
#
# Use `_`
#
# ---
#
# ## 59. Nested Tuple Unpacking
#
# ---
#
# ## 60. Build a Calculator Returning Multiple Values
#
# ---
#
# # 🟢 Level 7 — Nested Tuples (10 Problems)
#
# ---
#
# ## 61. Create a Nested Tuple
#
# ---
#
# ## 62. Access Nested Elements
#
# ---
#
# ## 63. Print Every Nested Tuple
#
# ---
#
# ## 64. Find the Sum of Every Nested Tuple
#
# ---
#
# ## 65. Find the Largest Value
#
# ---
#
# ## 66. Find the Smallest Value
#
# ---
#
# ## 67. Print a Matrix Stored as Tuples
#
# ---
#
# ## 68. Traverse a Nested Tuple
#
# ---
#
# ## 69. Find a Student's Marks
#
# ---
#
# ## 70. Build an Employee Record Using Nested Tuples
#
# ---
#
# # 🟢 Level 8 — Logic Building (10 Problems)
#
# ---
#
# ## 71. Remove Duplicate Elements
#
# ---
#
# ## 72. Find Unique Elements
#
# ---
#
# ## 73. Reverse a Tuple Without Using Slicing
#
# ---
#
# ## 74. Check Whether a Tuple is a Palindrome
#
# ---
#
# ## 75. Find the Frequency of Every Element
#
# ---
#
# ## 76. Merge Two Tuples Without Duplicates
#
# ---
#
# ## 77. Find Common Elements Between Two Tuples
#
# ---
#
# ## 78. Find the Difference Between Two Tuples
#
# ---
#
# ## 79. Create a Coordinate System Using Tuples
#
# Store points like
#
# ```
# (2, 5)
# (4, 7)
# (8, 3)
# ```
#
# ---
#
# ## 80. Store Student Records Using Tuples
#
# Example
#
# ```
# ("Siva", 23, "CSE")
# ```
#
# ---
#
# # 🔴 Level 9 — Pre-DSA Tuple Challenges (10 Problems)
#
# These problems introduce how tuples are used in DSA.
#
# ---
#
# ## 81. Store Graph Edges Using Tuples
#
# ---
#
# ## 82. Store Coordinates of Points
#
# ---
#
# ## 83. Find the Distance Between Two Points
#
# ---
#
# ## 84. Sort Tuples by First Element
#
# ---
#
# ## 85. Sort Tuples by Second Element
#
# ---
#
# ## 86. Find the Maximum Pair
#
# ---
#
# ## 87. Merge Intervals (Basic Representation)
#
# Represent intervals as tuples.
#
# ---
#
# ## 88. Represent Matrix Coordinates
#
# Store `(row, column)` pairs.
#
# ---
#
# ## 89. Priority Queue Data Representation
#
# Store
#
# ```
# (priority, task)
# ```
#
# ---
#
# ## 90. Represent Chess Board Coordinates
#
# Store positions like
#
# ```
# (A, 1)
#
# (B, 5)
#
# (H, 8)
# ```
#
# ---
#
# # ⭐ Bonus Projects
#
# 1. Student Record Management System
# 2. Employee Database
# 3. GPS Coordinate Tracker
# 4. RGB Color Palette Manager
# 5. Chess Board Coordinate System
# 6. Flight Booking Records
# 7. Train Seat Allocation
# 8. Hospital Patient Records
# 9. Weather Data Logger
# 10. Quiz Scoreboard
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|-----------------------------|---------:|
# | 🟢 Level 1 | Tuple Fundamentals | 10 |
# | 🟢 Level 2 | Accessing Tuples | 10 |
# | 🟢 Level 3 | Tuple Operations | 10 |
# | 🟢 Level 4 | Immutability | 10 |
# | 🟢 Level 5 | Tuple Methods | 10 |
# | 🟢 Level 6 | Packing & Unpacking | 10 |
# | 🟢 Level 7 | Nested Tuples | 10 |
# | 🟢 Level 8 | Logic Building | 10 |
# | 🔴 Level 9 | Pre-DSA Challenges | 10 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 100**
#
# ---
#
# # 🎯 Skills You'll Master
#
# By completing these challenges, you'll confidently understand:
#
# - ✅ Tuple creation
# - ✅ Tuple indexing and slicing
# - ✅ Tuple operations
# - ✅ Immutability
# - ✅ Tuple methods (`count()`, `index()`)
# - ✅ Packing and unpacking
# - ✅ Nested tuples
# - ✅ Using tuples as dictionary keys
# - ✅ Returning multiple values from functions
# - ✅ Tuple-based data representation in DSA
# - ✅ Real-world applications of tuples
#
# > **🚀 DSA Readiness:** After solving these 100 problems, you'll be comfortable using tuples in graph representations, coordinate systems, interval problems, priority queues, matrices, and other common DSA scenarios where immutable ordered data is preferred.

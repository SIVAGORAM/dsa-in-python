# %% [markdown]
# # 🐍 Python Dictionaries Mastery Challenge (70 Problems)
#
# > **Goal:** Master Python Dictionaries from beginner to advanced level and build a strong foundation for HashMap-based Data Structures and Algorithms (DSA).
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Create and manipulate dictionaries.
# - Access and update key-value pairs.
# - Master all built-in dictionary methods.
# - Iterate through dictionaries efficiently.
# - Build nested dictionaries.
# - Use dictionary comprehensions.
# - Solve real-world problems using dictionaries.
# - Understand hashing and HashMaps.
# - Prepare for dictionary-based DSA problems.
#
# ---
#
# # 🟢 Level 1 — Dictionary Fundamentals (10 Problems)
#
# > Learn the basics of dictionaries.
#
# ---
#
# ## 1. Create an Empty Dictionary
#
# Create an empty dictionary using different methods.
#
# ---
#
# ## 2. Create a Dictionary
#
# Create a dictionary containing student information.
#
# Example
#
# ```
# {
#     "name": "Siva",
#     "age": 23,
#     "city": "Kurnool"
# }
# ```
#
# ---
#
# ## 3. Create a Dictionary Using `dict()`
#
# Create the same dictionary using the `dict()` constructor.
#
# ---
#
# ## 4. Create a Dictionary from Two Lists
#
# Given
#
# ```
# keys = ["name", "age", "city"]
#
# values = ["Siva", 23, "Kurnool"]
# ```
#
# Create a dictionary.
#
# ---
#
# ## 5. Create a Dictionary from a List of Tuples
#
# Example
#
# ```
# [("a",1),("b",2),("c",3)]
# ```
#
# ---
#
# ## 6. Find the Length of a Dictionary
#
# Print the total number of key-value pairs.
#
# ---
#
# ## 7. Print All Keys
#
# Print every key in the dictionary.
#
# ---
#
# ## 8. Print All Values
#
# Print every value in the dictionary.
#
# ---
#
# ## 9. Print All Key-Value Pairs
#
# Display each key and its corresponding value.
#
# ---
#
# ## 10. Check Whether a Key Exists
#
# Determine whether a given key is present in a dictionary.
#
# ---
#
# # 🟢 Level 2 — Accessing & Updating Dictionaries (10 Problems)
#
# ---
#
# ## 11. Access a Value Using a Key
#
# Retrieve the value associated with a given key.
#
# ---
#
# ## 12. Access Using `get()`
#
# Retrieve a value safely using `get()`.
#
# ---
#
# ## 13. Add a New Key-Value Pair
#
# Add a new entry to a dictionary.
#
# ---
#
# ## 14. Update an Existing Value
#
# Modify the value associated with a key.
#
# ---
#
# ## 15. Update Multiple Values
#
# Update several key-value pairs at once.
#
# ---
#
# ## 16. Merge Two Dictionaries
#
# Combine two dictionaries into one.
#
# ---
#
# ## 17. Rename a Dictionary Key
#
# Replace an old key with a new key.
#
# ---
#
# ## 18. Replace Every Integer Value with Its Square
#
# Update all integer values.
#
# ---
#
# ## 19. Replace Empty Values
#
# Replace all `None` values with `"Not Available"`.
#
# ---
#
# ## 20. Create a Dictionary from User Input
#
# Accept key-value pairs from the user and build a dictionary.
#
# ---
#
# # 🟢 Level 3 — Dictionary Methods (10 Problems)
#
# ---
#
# ## 21. Use `keys()`
#
# Print all dictionary keys.
#
# ---
#
# ## 22. Use `values()`
#
# Print all values.
#
# ---
#
# ## 23. Use `items()`
#
# Print every key-value pair.
#
# ---
#
# ## 24. Use `pop()`
#
# Remove a specific key.
#
# ---
#
# ## 25. Use `popitem()`
#
# Remove the last inserted key-value pair.
#
# ---
#
# ## 26. Use `clear()`
#
# Remove all entries.
#
# ---
#
# ## 27. Use `copy()`
#
# Create a copy of a dictionary.
#
# ---
#
# ## 28. Use `update()`
#
# Update one dictionary with another.
#
# ---
#
# ## 29. Use `setdefault()`
#
# Insert a default value if a key doesn't exist.
#
# ---
#
# ## 30. Use `fromkeys()`
#
# Create a new dictionary from a list of keys.
#
# ---
#
# # 🟢 Level 4 — Iterating Over Dictionaries (10 Problems)
#
# ---
#
# ## 31. Iterate Over Keys
#
# Print all keys.
#
# ---
#
# ## 32. Iterate Over Values
#
# Print all values.
#
# ---
#
# ## 33. Iterate Over Items
#
# Print key-value pairs.
#
# ---
#
# ## 34. Print Keys in Sorted Order
#
# Sort dictionary keys before printing.
#
# ---
#
# ## 35. Print Values in Sorted Order
#
# Sort values before printing.
#
# ---
#
# ## 36. Print Dictionary with Index Numbers
#
# Use `enumerate()` while iterating.
#
# ---
#
# ## 37. Count Total Integer Values
#
# Iterate and count integer values.
#
# ---
#
# ## 38. Calculate the Sum of Numeric Values
#
# Find the total of all numeric values.
#
# ---
#
# ## 39. Print Only Even Values
#
# Display only even integer values.
#
# ---
#
# ## 40. Print Only Keys Starting with a Specific Letter
#
# Example: Keys beginning with `"a"`.
#
# ---
#
# # 🟢 Level 5 — Nested Dictionaries (10 Problems)
#
# ---
#
# ## 41. Create a Nested Dictionary
#
# Store multiple students in one dictionary.
#
# ---
#
# ## 42. Access Nested Values
#
# Print a student's city.
#
# ---
#
# ## 43. Update Nested Values
#
# Change a student's age.
#
# ---
#
# ## 44. Add a New Student
#
# Insert another nested dictionary.
#
# ---
#
# ## 45. Delete a Student Record
#
# Remove one nested dictionary.
#
# ---
#
# ## 46. Print All Student Names
#
# Traverse nested dictionaries.
#
# ---
#
# ## 47. Calculate Average Marks
#
# Store marks and compute averages.
#
# ---
#
# ## 48. Employee Database
#
# Store employee details using nested dictionaries.
#
# ---
#
# ## 49. Product Inventory
#
# Create an inventory system.
#
# ---
#
# ## 50. Library Management System
#
# Store books and their information.
#
# ---
#
# # 🟢 Level 6 — Dictionary Comprehensions (10 Problems)
#
# ---
#
# ## 51. Create Squares Dictionary
#
# ```
# 1 → 1
#
# 2 → 4
#
# 3 → 9
# ```
#
# ---
#
# ## 52. Create Cubes Dictionary
#
# Store cubes from 1–10.
#
# ---
#
# ## 53. Filter Even Numbers
#
# Create a dictionary containing only even values.
#
# ---
#
# ## 54. Filter Odd Numbers
#
# Create a dictionary containing only odd values.
#
# ---
#
# ## 55. Convert Values to Uppercase
#
# Convert all string values.
#
# ---
#
# ## 56. Swap Keys and Values
#
# Reverse a dictionary.
#
# ---
#
# ## 57. Remove Negative Values
#
# Create a new dictionary excluding negative values.
#
# ---
#
# ## 58. Create Dictionary from a List
#
# Using dictionary comprehension.
#
# ---
#
# ## 59. Word Length Dictionary
#
# ```
# Python → 6
# ```
#
# ---
#
# ## 60. Character Frequency Dictionary
#
# Count each character in a string.
#
# ---
#
# # 🟢 Level 7 — Logic Building (10 Problems)
#
# ---
#
# ## 61. Count Word Frequency
#
# Given a sentence, count each word.
#
# ---
#
# ## 62. Count Character Frequency
#
# Find how many times every character appears.
#
# ---
#
# ## 63. Find Duplicate Values
#
# Identify repeated values.
#
# ---
#
# ## 64. Find the Key with the Maximum Value
#
# Return the highest-scoring key.
#
# ---
#
# ## 65. Find the Key with the Minimum Value
#
# Return the lowest-scoring key.
#
# ---
#
# ## 66. Group Students by Grade
#
# Group students based on grades.
#
# ---
#
# ## 67. Create a Phone Book
#
# Store names and phone numbers.
#
# ---
#
# ## 68. Shopping Cart System
#
# Store products and quantities.
#
# ---
#
# ## 69. Student Marks Management
#
# Store marks and calculate totals.
#
# ---
#
# ## 70. Inventory Management System
#
# Track products and stock quantities.
#
# ---
#
# # 🔴 Level 8 — Pre-DSA Dictionary Challenges (15 Problems)
#
# These problems prepare you for HashMap-based DSA.
#
# ---
#
# ## 71. Two Sum
#
# ---
#
# ## 72. Valid Anagram
#
# ---
#
# ## 73. Group Anagrams
#
# ---
#
# ## 74. Majority Element
#
# ---
#
# ## 75. Top K Frequent Elements
#
# ---
#
# ## 76. First Unique Character
#
# ---
#
# ## 77. Isomorphic Strings
#
# ---
#
# ## 78. Word Pattern
#
# ---
#
# ## 79. Find Duplicate Files (Basic)
#
# ---
#
# ## 80. Roman to Integer
#
# ---
#
# ## 81. Integer to Roman
#
# ---
#
# ## 82. Ransom Note
#
# ---
#
# ## 83. Happy Number
#
# ---
#
# ## 84. Longest Consecutive Sequence
#
# ---
#
# ## 85. LRU Cache (Basic Idea)
#
# ---
#
# # ⭐ Bonus Projects
#
# 1. Student Database Management
# 2. Library Management System
# 3. Contact Book
# 4. Employee Management System
# 5. Banking System
# 6. Product Inventory Tracker
# 7. Expense Tracker
# 8. Online Shopping Cart
# 9. Voting System
# 10. Weather Data Analyzer
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|-------------------------------|---------:|
# | 🟢 Level 1 | Dictionary Fundamentals | 10 |
# | 🟢 Level 2 | Accessing & Updating | 10 |
# | 🟢 Level 3 | Dictionary Methods | 10 |
# | 🟢 Level 4 | Iteration | 10 |
# | 🟢 Level 5 | Nested Dictionaries | 10 |
# | 🟢 Level 6 | Dictionary Comprehensions | 10 |
# | 🟢 Level 7 | Logic Building | 10 |
# | 🔴 Level 8 | Pre-DSA HashMap Problems | 15 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 95**
#
# ---
#
# # 🎯 Skills You'll Master
#
# By completing these challenges, you'll confidently understand:
#
# - ✅ Creating dictionaries
# - ✅ Accessing and updating values
# - ✅ Dictionary methods
# - ✅ Iteration techniques
# - ✅ Nested dictionaries
# - ✅ Dictionary comprehensions
# - ✅ Hashing concepts
# - ✅ Frequency counting
# - ✅ Real-world applications
# - ✅ HashMap problem-solving patterns
# - ✅ Pre-DSA interview questions
#
# > **🚀 DSA Readiness:** After solving these 95 problems, you'll have a strong foundation for HashMap-based algorithms such as Two Sum, Group Anagrams, Sliding Window, Graphs, Dynamic Programming (Memoization), and other common coding interview problems.

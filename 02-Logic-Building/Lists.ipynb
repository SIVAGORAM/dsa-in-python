# %% [markdown]
# # 🐍 Python Lists Mastery Challenge (150+ Problems)
#
# > **Goal:** Master Python Lists and build strong logical thinking before starting Arrays in DSA.
#
# ---
#
# # 🟢 Level 1 — List Fundamentals (15 Problems)
#
# > Learn how lists work.
#
# 1. Create an empty list.
# 2. Create a list of integers.
# 3. Create a list of strings.
# 4. Create a mixed data type list.
# 5. Print all elements of a list.
# 6. Find the length of a list.
# 7. Access the first element.
# 8. Access the last element.
# 9. Access the middle element.
# 10. Access elements using negative indexing.
# 11. Check whether an element exists in a list.
# 12. Print the type of every element.
# 13. Create a list using `list()`.
# 14. Create a list using `range()`.
# 15. Create a list from user input.
#
# ---
#
# # 🟢 Level 2 — Accessing & Modifying Lists (15 Problems)
#
# 1. Update the first element.
# 2. Update the last element.
# 3. Replace multiple elements using slicing.
# 4. Swap two elements.
# 5. Replace all negative numbers with zero.
# 6. Replace all even numbers with -1.
# 7. Double every element.
# 8. Square every element.
# 9. Cube every element.
# 10. Convert all strings to uppercase.
# 11. Convert all strings to lowercase.
# 12. Remove leading and trailing spaces.
# 13. Replace vowels with '*'.
# 14. Reverse every string in a list.
# 15. Modify elements using indexes.
#
# ---
#
# # 🟢 Level 3 — Adding & Removing Elements (15 Problems)
#
# 1. Append an element.
# 2. Extend one list with another.
# 3. Insert an element at a specific index.
# 4. Remove an element by value.
# 5. Remove an element by index.
# 6. Delete the first element.
# 7. Delete the last element.
# 8. Delete multiple elements.
# 9. Clear the list.
# 10. Remove duplicate values.
# 11. Remove all even numbers.
# 12. Remove all odd numbers.
# 13. Remove all negative numbers.
# 14. Remove all zeros.
# 15. Remove empty strings.
#
# ---
#
# # 🟢 Level 4 — Traversing Lists (15 Problems)
#
# 1. Traverse using a `for` loop.
# 2. Traverse using a `while` loop.
# 3. Traverse using `enumerate()`.
# 4. Traverse using `range(len())`.
# 5. Traverse in reverse order.
# 6. Print only even-index elements.
# 7. Print only odd-index elements.
# 8. Print elements with their indexes.
# 9. Print every second element.
# 10. Print every third element.
# 11. Print elements in reverse using slicing.
# 12. Print elements using `reversed()`.
# 13. Print elements skipping negatives.
# 14. Print only positive numbers.
# 15. Print only duplicate elements.
#
# ---
#
# # 🟢 Level 5 — List Methods Practice (20 Problems)
#
# Practice every built-in method.
#
# 1. append()
# 2. extend()
# 3. insert()
# 4. remove()
# 5. pop()
# 6. clear()
# 7. copy()
# 8. count()
# 9. index()
# 10. reverse()
# 11. sort()
# 12. sorted()
# 13. max()
# 14. min()
# 15. sum()
# 16. len()
# 17. any()
# 18. all()
# 19. list()
# 20. del
#
# ---
#
# # 🟢 Level 6 — Searching Problems (15 Problems)
#
# 1. Linear Search.
# 2. Find index of an element.
# 3. Find all occurrences.
# 4. Count occurrences.
# 5. Check element exists.
# 6. Find largest element.
# 7. Find smallest element.
# 8. Find second largest.
# 9. Find second smallest.
# 10. Find maximum difference.
# 11. Find minimum difference.
# 12. Find duplicate elements.
# 13. Find unique elements.
# 14. Find missing number.
# 15. Find repeating number.
#
# ---
#
# # 🟢 Level 7 — List Mathematics (15 Problems)
#
# 1. Sum of list.
# 2. Product of list.
# 3. Average.
# 4. Count even numbers.
# 5. Count odd numbers.
# 6. Count positive numbers.
# 7. Count negative numbers.
# 8. Count zeros.
# 9. Find largest.
# 10. Find smallest.
# 11. Find range (max - min).
# 12. Calculate variance (basic).
# 13. Calculate standard deviation (basic).
# 14. Running sum.
# 15. Prefix sum.
#
# ---
#
# # 🟢 Level 8 — List Comprehension (15 Problems)
#
# 1. Squares.
# 2. Cubes.
# 3. Even numbers.
# 4. Odd numbers.
# 5. Positive numbers.
# 6. Negative numbers.
# 7. Uppercase strings.
# 8. Lowercase strings.
# 9. Reverse strings.
# 10. Filter vowels.
# 11. Matrix creation.
# 12. Flatten nested list.
# 13. Multiplication table.
# 14. Nested comprehension.
# 15. Conditional comprehension.
#
# ---
#
# # 🟢 Level 9 — Nested Lists & Matrix Problems (20 Problems)
#
# 1. Create a 2D list.
# 2. Print matrix.
# 3. Matrix traversal.
# 4. Row sum.
# 5. Column sum.
# 6. Primary diagonal sum.
# 7. Secondary diagonal sum.
# 8. Matrix addition.
# 9. Matrix subtraction.
# 10. Matrix transpose.
# 11. Matrix multiplication (basic).
# 12. Search in matrix.
# 13. Find largest element.
# 14. Find smallest element.
# 15. Count even numbers.
# 16. Count odd numbers.
# 17. Spiral traversal.
# 18. Snake traversal.
# 19. Rotate matrix 90°.
# 20. Print boundary elements.
#
# ---
#
# # 🟢 Level 10 — Logic Building (20 Problems)
#
# 1. Reverse a list.
# 2. Rotate left.
# 3. Rotate right.
# 4. Merge two lists.
# 5. Merge sorted lists.
# 6. Remove duplicates.
# 7. Move zeros to end.
# 8. Move negatives to beginning.
# 9. Separate even and odd numbers.
# 10. Find common elements.
# 11. Find union.
# 12. Find intersection.
# 13. Find difference.
# 14. Find symmetric difference.
# 15. Pair sum.
# 16. Pair difference.
# 17. Two Sum (Brute Force).
# 18. Leaders in array.
# 19. Maximum consecutive elements.
# 20. Majority element (basic).
#
# ---
#
# # 🟢 Level 11 — Sorting Practice (10 Problems)
#
# 1. Bubble Sort.
# 2. Selection Sort.
# 3. Insertion Sort.
# 4. Sort ascending.
# 5. Sort descending.
# 6. Sort strings.
# 7. Sort by length.
# 8. Custom sorting using `key`.
# 9. Sort list of tuples.
# 10. Sort list of dictionaries.
#
# ---
#
# # 🟢 Level 12 — Pre-DSA Challenges (20 Problems)
#
# These are excellent before Arrays.
#
# 1. Two Sum (Brute Force)
# 2. Running Sum
# 3. Prefix Sum
# 4. Pivot Index
# 5. Best Time to Buy and Sell Stock (Brute Force)
# 6. Contains Duplicate
# 7. Find Missing Number
# 8. Remove Duplicates from Sorted List
# 9. Merge Sorted Arrays
# 10. Rotate Array
# 11. Product Except Self (Brute Force)
# 12. Maximum Subarray (Brute Force)
# 13. Trapping Rain Water (Brute Force)
# 14. Container With Most Water (Brute Force)
# 15. Move Zeroes
# 16. Sort Colors (Basic)
# 17. Majority Element
# 18. Intersection of Arrays
# 19. Plus One
# 20. Pascals Triangle
#
# ---
#
# # ⭐ Challenge Summary
#
# | Level | Topic | Problems |
# |--------|------------------------------|---------:|
# | 1 | List Fundamentals | 15 |
# | 2 | Access & Modify | 15 |
# | 3 | Add & Remove | 15 |
# | 4 | Traversal | 15 |
# | 5 | List Methods | 20 |
# | 6 | Searching | 15 |
# | 7 | List Mathematics | 15 |
# | 8 | List Comprehensions | 15 |
# | 9 | Nested Lists & Matrix | 20 |
# | 10 | Logic Building | 20 |
# | 11 | Sorting | 10 |
# | 12 | Pre-DSA Challenges | 20 |
# | **Total** | **Python Lists Mastery Problems** | **195** |
#
# ---
#
# # 🎯 Learning Outcome
#
# After solving these 195 problems, you will confidently understand:
#
# - List creation and manipulation
# - Traversal techniques
# - Built-in list methods
# - Searching and sorting
# - Matrix operations
# - Nested lists
# - List comprehensions
# - Algorithmic thinking
# - Time and Space Complexity basics
# - Pre-DSA problem-solving patterns
#
# This prepares you to start **Arrays** in DSA with confidence.

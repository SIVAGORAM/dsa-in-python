# %% [markdown]
# # 🐍 Python `filter()` Mastery Challenge (100 Problems)
#
# > **Goal:** Master Python's `filter()` function from beginner to advanced level and understand when and how to use it effectively.
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Understand how `filter()` works.
# - Filter elements from any iterable.
# - Use `filter()` with normal functions.
# - Use `filter()` with lambda functions.
# - Filter numbers, strings, dictionaries, and objects.
# - Compare `filter()` with loops and list comprehensions.
# - Solve interview-style filtering problems.
#
# ---
#
# # 🟢 Level 1 — Understanding `filter()` (10 Problems)
#
# > Learn the basics of filtering.
#
# 1. Filter even numbers from a list.
# 2. Filter odd numbers.
# 3. Filter positive numbers.
# 4. Filter negative numbers.
# 5. Filter numbers greater than 50.
# 6. Filter numbers less than 20.
# 7. Filter numbers divisible by 3.
# 8. Filter numbers divisible by both 3 and 5.
# 9. Remove zeros from a list.
# 10. Remove duplicate numbers using `filter()`.
#
# ---
#
# # 🟢 Level 2 — `filter()` with Normal Functions (10 Problems)
#
# 11. Filter prime numbers.
# 12. Filter Armstrong numbers.
# 13. Filter palindrome numbers.
# 14. Filter leap years.
# 15. Filter perfect numbers.
# 16. Filter Fibonacci numbers.
# 17. Filter multiples of 7.
# 18. Filter numbers ending with 5.
# 19. Filter numbers greater than the average.
# 20. Filter numbers inside a given range.
#
# ---
#
# # 🟢 Level 3 — `filter()` with Lambda Functions (10 Problems)
#
# 21. Filter even numbers using lambda.
# 22. Filter odd numbers.
# 23. Filter positive numbers.
# 24. Filter negative numbers.
# 25. Filter numbers greater than 100.
# 26. Filter numbers less than 0.
# 27. Filter numbers divisible by 10.
# 28. Filter numbers whose square is greater than 100.
# 29. Filter numbers whose cube is less than 1000.
# 30. Filter non-zero values.
#
# ---
#
# # 🟢 Level 4 — Working with Strings (10 Problems)
#
# 31. Filter names longer than five characters.
# 32. Filter names shorter than four characters.
# 33. Filter words starting with a vowel.
# 34. Filter words ending with "ing".
# 35. Filter palindrome words.
# 36. Filter uppercase strings.
# 37. Filter lowercase strings.
# 38. Filter strings containing digits.
# 39. Filter strings containing only alphabets.
# 40. Remove empty strings from a list.
#
# ---
#
# # 🟢 Level 5 — Working with Lists (10 Problems)
#
# 41. Filter lists with more than five elements.
# 42. Filter lists containing an even number.
# 43. Filter lists whose sum is greater than 100.
# 44. Filter nested lists by length.
# 45. Filter lists containing duplicates.
# 46. Filter lists containing negative numbers.
# 47. Filter sorted lists.
# 48. Filter unsorted lists.
# 49. Filter lists containing only positive numbers.
# 50. Filter lists with an average greater than 50.
#
# ---
#
# # 🟢 Level 6 — Dictionaries & Objects (10 Problems)
#
# 51. Filter students who passed.
# 52. Filter students scoring above 90.
# 53. Filter employees earning more than ₹50,000.
# 54. Filter products costing less than ₹100.
# 55. Filter books published after 2020.
# 56. Filter active users.
# 57. Filter adults (age ≥ 18).
# 58. Filter employees from the IT department.
# 59. Filter products that are in stock.
# 60. Filter orders with status "Delivered".
#
# ---
#
# # 🟢 Level 7 — Real-World Problems (10 Problems)
#
# 61. Filter valid email addresses.
# 62. Filter valid phone numbers.
# 63. Filter strong passwords.
# 64. Filter students eligible for scholarships.
# 65. Filter vehicles older than 10 years.
# 66. Filter customers with pending payments.
# 67. Filter employees eligible for promotion.
# 68. Filter temperatures above normal.
# 69. Filter electricity bills above ₹1000.
# 70. Filter failed login attempts.
#
# ---
#
# # 🟢 Level 8 — `filter()` vs Loops (10 Problems)
#
# Rewrite each problem using both `filter()` and a `for` loop.
#
# 71. Filter even numbers.
# 72. Filter names longer than five characters.
# 73. Filter passed students.
# 74. Filter adults.
# 75. Filter positive numbers.
# 76. Filter prime numbers.
# 77. Filter valid emails.
# 78. Filter products in stock.
# 79. Filter employees by salary.
# 80. Remove empty strings.
#
# ---
#
# # 🟢 Level 9 — `filter()` vs List Comprehension (10 Problems)
#
# Rewrite each problem using both techniques.
#
# 81. Filter even numbers.
# 82. Filter odd numbers.
# 83. Filter positive numbers.
# 84. Filter negative numbers.
# 85. Filter palindrome words.
# 86. Filter names longer than five characters.
# 87. Filter passed students.
# 88. Filter adults.
# 89. Filter products above ₹500.
# 90. Remove empty strings.
#
# ---
#
# # 🔴 Level 10 — Interview & Logic Building (10 Problems)
#
# 91. Find students who scored above the class average.
# 92. Filter duplicate emails.
# 93. Find employees with both high salary and high experience.
# 94. Filter prime numbers from 1 to 1000.
# 95. Filter customers eligible for discounts.
# 96. Filter valid usernames.
# 97. Filter products with low stock.
# 98. Filter words containing every vowel.
# 99. Filter files larger than 10 MB.
# 100. Build a reusable custom filtering function.
#
# ---
#
# # ⭐ Bonus Mini Projects
#
# 1. Student Result Analyzer
# 2. Employee Management System
# 3. Product Inventory Manager
# 4. Email Validator
# 5. Password Strength Checker
# 6. Banking Transaction Filter
# 7. Expense Tracker
# 8. Library Book Filter
# 9. Hospital Patient Filter
# 10. Weather Data Cleaner
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|-----------------------------|---------:|
# | 🟢 Level 1 | Understanding `filter()` | 10 |
# | 🟢 Level 2 | Normal Functions | 10 |
# | 🟢 Level 3 | Lambda Functions | 10 |
# | 🟢 Level 4 | Strings | 10 |
# | 🟢 Level 5 | Lists | 10 |
# | 🟢 Level 6 | Dictionaries & Objects | 10 |
# | 🟢 Level 7 | Real-World Problems | 10 |
# | 🟢 Level 8 | `filter()` vs Loops | 10 |
# | 🟢 Level 9 | `filter()` vs List Comprehension | 10 |
# | 🔴 Level 10 | Interview Challenges | 10 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 110**
#
# ---
#
# # 🎯 Skills You'll Master
#
# After solving these problems, you'll confidently understand:
#
# - ✅ `filter()` syntax
# - ✅ Filtering data using normal functions
# - ✅ Filtering data using lambda functions
# - ✅ Filtering strings, lists, and dictionaries
# - ✅ Filtering objects
# - ✅ Data validation
# - ✅ Data cleaning
# - ✅ Functional programming concepts
# - ✅ Comparing `filter()`, loops, and list comprehensions
# - ✅ Interview-level filtering problems
#
# ---
#
# # 🚀 DSA Readiness
#
# Although `filter()` is not a core DSA algorithm, it is widely used for:
#
# - Preprocessing input data
# - Removing unwanted elements
# - Validating datasets
# - Preparing arrays before applying algorithms
# - Writing concise Python code in coding interviews
# - Combining with `map()`, `reduce()`, `sorted()`, `zip()`, and `enumerate()`
#
# Mastering `filter()` will help you write cleaner, more expressive, and more Pythonic code.

# %% [markdown]
# # 🐍 Python Functions Mastery Challenge (120 Problems)
#
# > **Goal:** Master Python Functions from beginner to advanced level and build a strong foundation for Data Structures & Algorithms (DSA).
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Define and call functions.
# - Pass different types of arguments.
# - Return values effectively.
# - Understand scope and lifetime of variables.
# - Work with recursion.
# - Master lambda functions.
# - Build reusable and modular programs.
# - Understand functions used in DSA.
#
# ---
#
# # 🟢 Level 1 — Function Fundamentals (10 Problems)
#
# > Learn the basics of functions.
#
# 1. Create a function to print "Hello, World!".
# 2. Create a function to print your name.
# 3. Create a function to print your college name.
# 4. Create a function to print your favorite programming language.
# 5. Call the same function five times.
# 6. Create multiple functions and call them in sequence.
# 7. Create a function without parameters.
# 8. Create a function that prints today's date.
# 9. Create a function that prints a welcome message.
# 10. Explain the difference between defining and calling a function.
#
# ---
#
# # 🟢 Level 2 — Function Parameters (10 Problems)
#
# 1. Create a function that accepts one parameter.
# 2. Create a function that accepts two numbers.
# 3. Find the sum of two numbers.
# 4. Find the product of two numbers.
# 5. Find the maximum of two numbers.
# 6. Find the minimum of two numbers.
# 7. Find the average of three numbers.
# 8. Print student details using parameters.
# 9. Print employee details using parameters.
# 10. Calculate the area of a rectangle.
#
# ---
#
# # 🟢 Level 3 — Return Statement (10 Problems)
#
# 1. Return the sum of two numbers.
# 2. Return the square of a number.
# 3. Return the cube of a number.
# 4. Return the factorial of a number.
# 5. Return whether a number is even or odd.
# 6. Return the largest among three numbers.
# 7. Return the smallest among three numbers.
# 8. Return the reverse of a string.
# 9. Return the length of a string.
# 10. Return the absolute value of a number.
#
# ---
#
# # 🟢 Level 4 — Default Parameters (10 Problems)
#
# 1. Create a greeting function with a default name.
# 2. Create a calculator with a default operator.
# 3. Calculate simple interest using a default rate.
# 4. Calculate salary with a default bonus.
# 5. Create a login function with a default role.
# 6. Create a shipping calculator with a default delivery charge.
# 7. Print employee details with a default department.
# 8. Create a student report with default grades.
# 9. Build a menu function with default options.
# 10. Experiment with multiple default parameters.
#
# ---
#
# # 🟢 Level 5 — Keyword Arguments (10 Problems)
#
# 1. Call a function using keyword arguments.
# 2. Mix positional and keyword arguments.
# 3. Create a student profile.
# 4. Create an employee profile.
# 5. Create a product information function.
# 6. Build a travel booking function.
# 7. Create a hospital registration function.
# 8. Create a movie booking function.
# 9. Create a bank account function.
# 10. Compare positional vs keyword arguments.
#
# ---
#
# # 🟢 Level 6 — Variable-Length Arguments (10 Problems)
#
# 1. Sum unlimited numbers using `*args`.
# 2. Find the largest number using `*args`.
# 3. Find the smallest number using `*args`.
# 4. Calculate the average using `*args`.
# 5. Print unlimited names.
# 6. Store employee details using `**kwargs`.
# 7. Store student details using `**kwargs`.
# 8. Build a product catalog using `**kwargs`.
# 9. Use both `*args` and `**kwargs` together.
# 10. Build a flexible calculator using variable-length arguments.
#
# ---
#
# # 🟢 Level 7 — Variable Scope (10 Problems)
#
# 1. Create a local variable.
# 2. Access a global variable.
# 3. Modify a global variable.
# 4. Demonstrate variable shadowing.
# 5. Use the `global` keyword.
# 6. Use the `nonlocal` keyword.
# 7. Explain LEGB rule with an example.
# 8. Compare local vs global variables.
# 9. Find scope errors in code.
# 10. Build a visitor counter using global variables.
#
# ---
#
# # 🟢 Level 8 — Lambda Functions (10 Problems)
#
# 1. Create a lambda function to add two numbers.
# 2. Square a number using lambda.
# 3. Find the maximum of two numbers.
# 4. Sort a list using lambda.
# 5. Sort tuples using lambda.
# 6. Use lambda with `map()`.
# 7. Use lambda with `filter()`.
# 8. Use lambda with `reduce()`.
# 9. Create an age sorting program.
# 10. Compare normal functions and lambda functions.
#
# ---
#
# # 🟢 Level 9 — Recursion (10 Problems)
#
# 1. Print numbers from 1 to N.
# 2. Print numbers from N to 1.
# 3. Calculate factorial recursively.
# 4. Calculate Fibonacci recursively.
# 5. Find the sum of natural numbers.
# 6. Calculate power recursively.
# 7. Reverse a string recursively.
# 8. Check palindrome recursively.
# 9. Count digits recursively.
# 10. Calculate GCD recursively.
#
# ---
#
# # 🟢 Level 10 — Built-in Functions (10 Problems)
#
# 1. Use `len()`.
# 2. Use `sum()`.
# 3. Use `max()`.
# 4. Use `min()`.
# 5. Use `sorted()`.
# 6. Use `enumerate()`.
# 7. Use `zip()`.
# 8. Use `map()`.
# 9. Use `filter()`.
# 10. Use `any()` and `all()`.
#
# ---
#
# # 🟢 Level 11 — Logic Building with Functions (20 Problems)
#
# 1. Prime number checker.
# 2. Armstrong number checker.
# 3. Palindrome checker.
# 4. Perfect number checker.
# 5. Leap year checker.
# 6. Calculator using functions.
# 7. Student grade calculator.
# 8. Electricity bill calculator.
# 9. ATM simulation.
# 10. Banking system.
# 11. Shopping cart.
# 12. Employee salary calculator.
# 13. Temperature converter.
# 14. Unit converter.
# 15. BMI calculator.
# 16. Voting eligibility checker.
# 17. Password validator.
# 18. Email validator.
# 19. Number guessing game.
# 20. Rock-Paper-Scissors game.
#
# ---
#
# # 🔴 Level 12 — Pre-DSA Function Challenges (20 Problems)
#
# > Learn how functions are used in algorithms.
#
# 1. Linear Search Function.
# 2. Binary Search Function.
# 3. Bubble Sort Function.
# 4. Selection Sort Function.
# 5. Insertion Sort Function.
# 6. Merge Sort Function.
# 7. Quick Sort Function.
# 8. Find Maximum Element.
# 9. Find Minimum Element.
# 10. Find Second Largest Element.
# 11. Reverse an Array.
# 12. Rotate an Array.
# 13. Prefix Sum Function.
# 14. Running Sum Function.
# 15. Two Sum Function.
# 16. Frequency Counter.
# 17. Character Counter.
# 18. Word Counter.
# 19. Matrix Addition Function.
# 20. Matrix Multiplication Function.
#
# ---
#
# # ⭐ Bonus Mini Projects
#
# 1. Student Management System
# 2. Employee Payroll System
# 3. Banking Application
# 4. Library Management System
# 5. Hotel Booking System
# 6. Hospital Management System
# 7. Quiz Application
# 8. Expense Tracker
# 9. Contact Book
# 10. Weather Dashboard
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|-------------------------------|---------:|
# | 🟢 Level 1 | Function Fundamentals | 10 |
# | 🟢 Level 2 | Parameters | 10 |
# | 🟢 Level 3 | Return Statement | 10 |
# | 🟢 Level 4 | Default Parameters | 10 |
# | 🟢 Level 5 | Keyword Arguments | 10 |
# | 🟢 Level 6 | *args & **kwargs | 10 |
# | 🟢 Level 7 | Variable Scope | 10 |
# | 🟢 Level 8 | Lambda Functions | 10 |
# | 🟢 Level 9 | Recursion | 10 |
# | 🟢 Level 10 | Built-in Functions | 10 |
# | 🟢 Level 11 | Logic Building | 20 |
# | 🔴 Level 12 | Pre-DSA Challenges | 20 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 140**
#
# ---
#
# # 🎯 Skills You'll Master
#
# By completing these challenges, you'll confidently understand:
#
# - ✅ Function definition and invocation
# - ✅ Parameters and arguments
# - ✅ Return values
# - ✅ Default, keyword, and variable-length arguments
# - ✅ Variable scope (Local, Global, Nonlocal)
# - ✅ Lambda functions
# - ✅ Recursion
# - ✅ Built-in functions
# - ✅ Modular programming
# - ✅ Function-based problem solving
# - ✅ Functions in DSA algorithms
#
# > **🚀 DSA Readiness:** After solving these 140 problems, you'll be comfortable writing clean, reusable, and efficient functions, making it much easier to implement searching, sorting, recursion, dynamic programming, graphs, trees, and other DSA algorithms.

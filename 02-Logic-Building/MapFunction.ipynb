# %% [markdown]
# # 🐍 Python `map()` Mastery Challenge (100 Problems)
#
# > **Goal:** Master Python's `map()` function from beginner to advanced level and understand when to use it effectively.
#
# ---
#
# # 📚 Learning Outcomes
#
# After completing this challenge, you will be able to:
#
# - Understand how `map()` works.
# - Apply functions to iterables.
# - Use `map()` with normal functions.
# - Use `map()` with lambda functions.
# - Work with multiple iterables.
# - Compare `map()` with loops and list comprehensions.
# - Solve interview-style problems.
#
# ---
#
# # 🟢 Level 1 — Understanding `map()` (10 Problems)
#
# > Learn the basics.
#
# 1. Square every number in a list using `map()`.
# 2. Cube every number.
# 3. Double every number.
# 4. Triple every number.
# 5. Add 10 to every element.
# 6. Subtract 5 from every element.
# 7. Convert integers to strings.
# 8. Convert strings to integers.
# 9. Convert floats to integers.
# 10. Convert strings to floats.
#
# ---
#
# # 🟢 Level 2 — `map()` with Normal Functions (10 Problems)
#
# 11. Find the square using a normal function.
# 12. Find the cube.
# 13. Find the absolute value.
# 14. Find the factorial.
# 15. Convert Celsius to Fahrenheit.
# 16. Convert Fahrenheit to Celsius.
# 17. Convert kilometers to miles.
# 18. Convert miles to kilometers.
# 19. Find the area of a circle.
# 20. Find the perimeter of a rectangle.
#
# ---
#
# # 🟢 Level 3 — `map()` with Lambda Functions (10 Problems)
#
# 21. Square numbers using lambda.
# 22. Cube numbers.
# 23. Add 100 to every element.
# 24. Multiply every number by 5.
# 25. Divide every number by 2.
# 26. Find the remainder when divided by 2.
# 27. Convert negative numbers to positive.
# 28. Find the reciprocal of every number.
# 29. Round decimal numbers.
# 30. Raise every number to the power of 3.
#
# ---
#
# # 🟢 Level 4 — Working with Strings (10 Problems)
#
# 31. Convert all strings to uppercase.
# 32. Convert all strings to lowercase.
# 33. Capitalize every word.
# 34. Convert every string to title case.
# 35. Remove leading spaces.
# 36. Remove trailing spaces.
# 37. Remove both leading and trailing spaces.
# 38. Find the length of every word.
# 39. Reverse every string.
# 40. Replace spaces with underscores.
#
# ---
#
# # 🟢 Level 5 — Multiple Iterables (10 Problems)
#
# 41. Add two lists element-wise.
# 42. Multiply two lists.
# 43. Find the maximum of two lists element-wise.
# 44. Find the minimum.
# 45. Concatenate first and last names.
# 46. Create email addresses.
# 47. Calculate total marks from two subject lists.
# 48. Find the difference between two lists.
# 49. Calculate discounts from price and percentage lists.
# 50. Create coordinate tuples from x and y lists.
#
# ---
#
# # 🟢 Level 6 — Real-World Problems (10 Problems)
#
# 51. Calculate employee bonuses.
# 52. Calculate net salary.
# 53. Calculate GST.
# 54. Apply a 10% discount.
# 55. Convert temperatures.
# 56. Calculate BMI.
# 57. Convert currencies.
# 58. Calculate electricity bills.
# 59. Convert student marks into grades.
# 60. Generate usernames.
#
# ---
#
# # 🟢 Level 7 — Objects & Dictionaries (10 Problems)
#
# 61. Extract names from a list of dictionaries.
# 62. Extract salaries.
# 63. Extract ages.
# 64. Increase every employee's salary.
# 65. Extract student marks.
# 66. Convert product prices to integers.
# 67. Create full names.
# 68. Format employee details.
# 69. Convert dictionaries into strings.
# 70. Calculate total prices.
#
# ---
#
# # 🟢 Level 8 — `map()` vs Loops (10 Problems)
#
# Rewrite each using both approaches.
#
# 71. Square numbers.
# 72. Convert to uppercase.
# 73. Find word lengths.
# 74. Convert temperatures.
# 75. Convert currencies.
# 76. Add two lists.
# 77. Calculate bonuses.
# 78. Calculate discounts.
# 79. Convert strings to integers.
# 80. Remove spaces.
#
# ---
#
# # 🟢 Level 9 — `map()` vs List Comprehension (10 Problems)
#
# Rewrite using both techniques.
#
# 81. Square numbers.
# 82. Cube numbers.
# 83. Capitalize words.
# 84. Convert strings to integers.
# 85. Reverse strings.
# 86. Find lengths.
# 87. Convert temperatures.
# 88. Multiply by 100.
# 89. Create email addresses.
# 90. Format names.
#
# ---
#
# # 🔴 Level 10 — Interview & Logic Building (10 Problems)
#
# 91. Create usernames from full names.
# 92. Format phone numbers.
# 93. Convert marks to grades.
# 94. Format dates.
# 95. Convert prices to currency strings.
# 96. Mask email addresses.
# 97. Generate employee IDs.
# 98. Convert words to Pig Latin.
# 99. Create initials from names.
# 100. Normalize user input.
#
# ---
#
# # ⭐ Bonus Challenges
#
# 1. Student Report Card Generator
# 2. Payroll Calculator
# 3. Temperature Converter
# 4. Currency Converter
# 5. Product Price Formatter
# 6. Employee Management System
# 7. User Profile Formatter
# 8. Online Shopping Cart
# 9. Banking Transaction Formatter
# 10. Data Cleaning Tool
#
# ---
#
# # 📊 Challenge Summary
#
# | Level | Topic | Problems |
# |--------|------------------------------|---------:|
# | 🟢 Level 1 | Understanding `map()` | 10 |
# | 🟢 Level 2 | Normal Functions | 10 |
# | 🟢 Level 3 | Lambda Functions | 10 |
# | 🟢 Level 4 | Strings | 10 |
# | 🟢 Level 5 | Multiple Iterables | 10 |
# | 🟢 Level 6 | Real-World Problems | 10 |
# | 🟢 Level 7 | Objects & Dictionaries | 10 |
# | 🟢 Level 8 | `map()` vs Loops | 10 |
# | 🟢 Level 9 | `map()` vs List Comprehension | 10 |
# | 🔴 Level 10 | Interview Challenges | 10 |
# | ⭐ Bonus | Mini Projects | 10 |
#
# ## **Total Practice Problems: 110**
#
# ---
#
# # 🎯 Skills You'll Master
#
# After solving these problems, you'll confidently understand:
#
# - ✅ `map()` syntax
# - ✅ Applying functions to iterables
# - ✅ Using `map()` with normal functions
# - ✅ Using `map()` with lambda functions
# - ✅ Working with multiple iterables
# - ✅ String transformations
# - ✅ Numeric transformations
# - ✅ Data formatting
# - ✅ Data cleaning
# - ✅ Functional programming basics
# - ✅ Interview-level `map()` questions
#
# ---
#
# # 🚀 DSA Readiness
#
# Although `map()` is not a core DSA topic, it is extremely useful for:
#
# - Preprocessing input data
# - Transforming arrays and lists
# - Cleaning datasets
# - Formatting outputs
# - Writing concise Python code in coding interviews
# - Combining with `filter()`, `zip()`, `sorted()`, and `enumerate()`
#
# Mastering `map()` will make your Python code cleaner and help you write more expressive solutions during interviews.
